# %%
#imports
import numpy as np
from utils import objects as ob
from utils import soa as SOA

# %%
#intializing multibodysystem
robot = ob.MultiBodySystem()

#defining joints
joint3 = ob.FreeJoint()
joint2 = ob.SphericalJoint()
joint1 = ob.RevoluteJoint(axis="z")    

#intialziing such that pendulum is hanging to the right

#joint3.q_init = np.concatenate((SOA.quatfromrev(np.pi/2,"y"), np.zeros(3)))
#joint2.w_init = np.array([1,1,2])

#defining links
link3 = ob.Link(mass=2.0, l_hinge=np.array([0, 0, 0.2]), joint=joint3)
link2 = ob.Link(mass=1.0, l_hinge=np.array([0, 0, 0.2]), joint=joint2)
link1 = ob.Link(mass=0.5, l_hinge=np.array([0, 0, 0.2]), joint=joint1)

#adding links - build base out
robot.add_link(link3)
robot.add_link(link2)
robot.add_link(link1)

# %%
#parameters for ssimulation
tspan = np.arange(0,10,0.001)
V_base = np.zeros(6)
A_base = np.zeros(6)
A_base[-1] = 9.81 #simulating gravity in z

robot.simulate(tspan,V_base,A_base,"open")
# Out:
# Simulation started (open-loop configuration)
# t = 0.00 s
# t = 1.00 s
# t = 2.00 s
# t = 2.00 s
# t = 3.00 s
# t = 3.00 s
# t = 4.00 s
# t = 5.00 s
# t = 6.00 s
# t = 7.00 s
# t = 8.00 s
# t = 8.00 s
# t = 9.00 s
# t = 9.00 s
# Simulation finished

# %%
robot.plot_gen_velocities()
